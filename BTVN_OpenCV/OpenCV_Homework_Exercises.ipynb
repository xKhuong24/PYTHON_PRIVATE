# %% [markdown]
# # BÀI TẬP VỀ NHÀ - OPENCV VỚI PYTHON
#
# **Lưu ý**: Có những kiến thức chưa được cung cấp trên lớp anh đã note lại ở từng bài các bạn có chủ động tìm hiêu, những phần mà chưa kiến thức đó anh đã để luôn code vậy nên các em có thể sử dụng chúng để research thêm
#
# **Mô tả**: Notebook này bao gồm các bài tập thực hành OpenCV từ cơ bản đến nâng cao. Mỗi bài tập có đề bài rõ ràng và code mẫu giải đáp.
#
# **Yêu cầu**:
# - Python 3.x
# - OpenCV (`pip install opencv-python`)
# - NumPy (`pip install numpy`)
# - Matplotlib (`pip install matplotlib`)
#
# ---

# %% [markdown]
# ## PHẦN 1: CƠ BẢN (BASICS)
#
# ### Bài 1: Đọc và Hiển thị Ảnh, Video
#
# **Đề bài:**
# 1. Đọc và hiển thị ảnh từ file `Resources/Photos/cats.jpg`
# 2. Đọc và hiển thị video từ file `Resources/Videos/dog.mp4`
# 3. Cho phép người dùng nhấn phím 'd' để thoát khỏi video
#
# **Mục tiêu học tập:**
# - Sử dụng `cv.imread()` để đọc ảnh
# - Sử dụng `cv.VideoCapture()` để đọc video
# - Hiểu về vòng lặp đọc video frame-by-frame
# - Quản lý tài nguyên với `release()` và `destroyAllWindows()`

# %%
### CODE GIẢI BÀI 1

import cv2 as cv

# Phần 1: Đọc và hiển thị ảnh
meo = cv.imread('Resources/Photos/cats.jpg')
cv.imshow("Cat" , meo)
print("Đang hiện ảnh")
cv.waitKey(0)
cv.destroyAllWindows()
# Phần 2: Đọc và hiển thị video
capture = cv.VideoCapture('Resources/Videos/dog.mp4')
print("Đang phát video bấm d để thoát")
while True:
    isTrue, frame = capture.read()

    if not isTrue:
        break
    cv.imshow('Video Dog', frame)
    if cv.waitKey(20) & 0xFF == ord('d'):
            break
# Giải phóng tài nguyên
capture.release()
cv.destroyAllWindows()
print("Hoàn thành bài 1!")
# Out:
# Đang hiện ảnh
# Đang phát video bấm d để thoát
# Hoàn thành bài 1!

# %% [markdown]
# ---
#
# ### Bài 2: Vẽ Hình và Viết Chữ
#
# **Đề bài:**
# 1. Tạo một canvas trắng kích thước 500x500 pixels
# 2. Vẽ một hình chữ nhật màu xanh lá cây ở góc trên bên trái
# 3. Vẽ một hình tròn màu đỏ ở giữa canvas
# 4. Vẽ một đường thẳng màu trắng
# 5. Viết text "OpenCV Tutorial" lên canvas
# 6. Tô một vùng nhỏ màu đỏ trên canvas bằng array slicing
#
# **Mục tiêu học tập:**
# - Tạo blank image với NumPy
# - Sử dụng `cv.rectangle()`, `cv.circle()`, `cv.line()`
# - Sử dụng `cv.putText()` để viết text
# - Hiểu về màu sắc BGR trong OpenCV
# - Sử dụng array slicing để thay đổi pixel

# %%
### CODE GIẢI BÀI 2

import cv2 as cv
import numpy as np

# Tạo canvas trắng 500x500 pixels, 3 channels (BGR)
blank =np.zeros((500, 500, 3), dtype='uint8')
blank[:] = 255
# 1. Tô một vùng màu đỏ (BGR: 0,0,255)
blank[200:300, 300:400] = 0, 0, 255
# 2. Vẽ hình chữ nhật màu xanh lá (BGR: 0,255,0)
# Tham số: image, điểm bắt đầu, điểm kết thúc, màu, độ dày (-1 = fill)
cv.rectangle(blank, (0,0), (250,200), (0,255,0), thickness=-1)
# 3. Vẽ hình tròn màu đỏ ở giữa
# Tham số: image, tâm, bán kính, màu, độ dày
cv.circle(blank, (250,250), 45, (0,0,255), thickness=2)
# 4. Vẽ đường thẳng màu trắng
# Tham số: image, điểm bắt đầu, điểm kết thúc, màu, độ dày
cv.line(blank, (450,250), (450,500), (0,0,0), thickness=3)
# 5. Viết text
# Tham số: image, text, vị trí, font, font scale, màu, độ dày
cv.putText(blank, 'Sao E No', (0, 225), cv.FONT_HERSHEY_TRIPLEX, 1.0, (222,255,0), 2)
cv.imshow('Hinh', blank)
cv.waitKey(0)
cv.destroyAllWindows()
print("Hoàn thành bài 2!")
# Out:
# Hoàn thành bài 2!

# %% [markdown]
# ---
#
# ### Bài 3: Các Hàm Cơ Bản trong OpenCV
#
# **Đề bài:**
# Áp dụng các phép biến đổi sau lên ảnh `Resources/Photos/park.jpg`:
# 1. Chuyển đổi sang ảnh grayscale (xám)
# 2. Làm mờ ảnh bằng Gaussian Blur với kernel 7x7
# 3. Phát hiện cạnh bằng Canny Edge Detection
# 4. Làm dày (dilate) các cạnh đã phát hiện
# 5. Làm mỏng (erode) ảnh đã dilate
# 6. Resize ảnh về kích thước 500x500
# 7. Cắt (crop) một vùng của ảnh
#
# **Mục tiêu học tập:**
# - Chuyển đổi color space với `cv.cvtColor()`
# - Làm mờ ảnh với `cv.GaussianBlur()`
# - Phát hiện cạnh với `cv.Canny()`
# - Morphological operations: `cv.dilate()`, `cv.erode()`
# - Resize và crop ảnh

# %%
### CODE GIẢI BÀI 3

import cv2 as cv

# Đọc ảnh
img = cv.imread('Resources/Photos/park.jpg')
cv.imshow('Origin', img)
# 1. Chuyển đổi sang grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Gray', gray)
# 2. Làm mờ với Gaussian Blur
# Tham số: image, kernel size (phải là số lẻ), border type
blur = cv.GaussianBlur(img, (7,7), cv.BORDER_DEFAULT)
cv.imshow('Blur', blur)
# 3. Phát hiện cạnh với Canny
# Tham số: image, threshold1, threshold2
canny =cv.Canny(blur, 125, 175)
cv.imshow('Canny', canny)
# 4. Dilating (làm dày) - mở rộng vùng trắng
kernel =np.ones((5,5), np.uint8)
dilate = cv.dilate(canny, kernel, iterations=1)
cv.imshow('Dilate', dilate)
# 5. Eroding (làm mỏng) - thu nhỏ vùng trắng
erode = cv.erode(dilate, kernel, iterations=1)
cv.imshow('Erode', erode)
# 6. Resize ảnh về 500x500
# Tham số: image, new size, interpolation method
resize = cv.resize(img, (500,500), interpolation=cv.INTER_CUBIC)
cv.imshow('Resize', resize)
# 7. Cropping - cắt một vùng [y1:y2, x1:x2]
crop = img[50:200, 200:400]
cv.imshow('Crop', crop)

cv.waitKey(0)
cv.destroyAllWindows()
print("Hoàn thành bài 3!")
# Out:
# Hoàn thành bài 3!

# %% [markdown]
# ---
#
# ### Bài 4: Phép Biến Đổi Hình Học (Transformations)
#
# **Đề bài:**
# Thực hiện các phép biến đổi sau trên ảnh `Resources/Photos/park.jpg`:
# 1. Tịnh tiến (translate) ảnh sang trái 100 pixels và xuống dưới 100 pixels
# 2. Xoay (rotate) ảnh -45 độ quanh tâm
# 3. Xoay ảnh -90 độ
# 4. Lật (flip) ảnh theo cả hai trục
#
# **Mục tiêu học tập:**
# - Tạo translation matrix và sử dụng `cv.warpAffine()`
# - Tạo rotation matrix với `cv.getRotationMatrix2D()`
# - Sử dụng `cv.flip()` để lật ảnh
# - Hiểu về affine transformations

# %%
### CODE GIẢI BÀI 4

import cv2 as cv
import numpy as np

img = cv.imread('Resources/Photos/park.jpg')
cv.imshow('Original', img)

# 1. TRANSLATION (Tịnh tiến)

# Tịnh tiến sang trái 100px, xuống 100px
transMat=np.float32([[1,0,-100],[0,1,100]])
trans=cv.warpAffine(img,transMat,img.shape[:2][::-1])
cv.imshow('translate', trans)
# HƯỚNG DẪN THÊM CHO CÁC BẠN
# 2. ROTATION (Xoay)
def rotate(img, angle, rotPoint=None):
    """
    Xoay ảnh quanh một điểm
    angle: góc xoay (dương = ngược chiều kim đồng hồ)
    rotPoint: tâm xoay (mặc định là tâm ảnh)
    """
    (height, width) = img.shape[:2]
    
    if rotPoint is None:
        rotPoint = (width // 2, height // 2)
    
    # Tạo rotation matrix: (tâm, góc, scale)
    rotMat = cv.getRotationMatrix2D(rotPoint, angle, 1.0)
    dimensions = (width, height)
    
    return cv.warpAffine(img, rotMat, dimensions)

# Xoay -45 độ
r1 = rotate(img, -45)
cv.imshow('Rotate 45',r1)

# Xoay -90 độ
r2 = rotate(img, -90)
cv.imshow('Rotate 90', r2)

# 3. FLIPPING (Lật)
# flipCode: 0 = lật theo trục x, 1 = lật theo trục y, -1 = lật cả hai
flip=cv.flip(img,-1)
cv.imshow('flip',flip)

cv.waitKey(0)
cv.destroyAllWindows()

print("Hoàn thành bài 4!")
# Out:
# Hoàn thành bài 4!

# %% [markdown]
# ---
#
# ### Bài 5: Phát Hiện Contours (Đường Viền)
#
# **Đề bài:**
# 1. Đọc ảnh `Resources/Photos/cats.jpg`
# 2. Chuyển sang grayscale và làm mờ
# 3. Phát hiện cạnh bằng Canny
# 4. Tìm tất cả contours trong ảnh
# 5. Vẽ các contours lên một canvas trắng
# 6. In ra số lượng contours tìm được
#
# **Mục tiêu học tập:**
# - Sử dụng `cv.findContours()` để tìm đường viền
# - Hiểu về retrieval modes và approximation methods
# - Sử dụng `cv.drawContours()` để vẽ contours

# %%
### CODE GIẢI BÀI 5

import cv2 as cv
import numpy as np

# Đọc ảnh
img = cv.imread('Resources/Photos/cats.jpg')
cv.imshow('Cats', img)

# Tạo canvas trắng có cùng kích thước
blank =np.zeros((img.shape[0],img.shape[1]),dtype='uint8')
blank[:]=255
# Chuyển sang grayscale
gray =cv.cvtColor(img,cv.COLOR_BGR2GRAY)
# Làm mờ để giảm noise
blur=cv.GaussianBlur(gray,(7,7),cv.BORDER_DEFAULT)
# Phát hiện cạnh
canny=cv.Canny(blur,150,175)
# GIỚI THIỆU THÊM CHO CÁC BẠN
# Tìm contours
# cv.RETR_LIST: lấy tất cả contours
# cv.CHAIN_APPROX_SIMPLE: nén contours để tiết kiệm bộ nhớ
contours, hierarchies = cv.findContours(canny, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
print(f'Tìm thấy {len(contours)} contour(s)!')

# Vẽ contours
# Tham số: image, contours list, contour index (-1 = all), color, thickness
cv.drawContours(blank, contours, -1, (0, 0, 255), 1)
cv.imshow('Contours Drawn', blank)

cv.waitKey(0)
cv.destroyAllWindows()

print("Hoàn thành bài 5!")
# Out:
# Tìm thấy 251 contour(s)!
# Hoàn thành bài 5!

# %% [markdown]
# ---
#
# ## PHẦN 2: NÂNG CAO (ADVANCED)
#
# ### Bài 6: Color Spaces (Không Gian Màu) Anh thấy cái này chưa được giới thiệu trên lớp các bạn nên tìm hiểu thêm về nó
#
# **Đề bài:**
# Chuyển đổi ảnh `Resources/Photos/park.jpg` sang các color spaces khác nhau:
# 1. BGR → Grayscale
# 2. BGR → HSV
# 3. BGR → LAB
# 4. BGR → RGB
# 5. LAB → BGR (chuyển ngược lại)
#
# **Mục tiêu học tập:**
# - Hiểu về các color spaces khác nhau
# - Sử dụng `cv.cvtColor()` với các conversion codes
# - Biết khi nào nên dùng color space nào

# %%
#### GIỚI THIỆU THÊM CHO CÁC BẠN VỀ CHUYỂN ĐỔI KHÔNG GIAN MÀU
### CODE GIẢI BÀI 6

import cv2 as cv

img = cv.imread('Resources/Photos/park.jpg')
cv.imshow('Original', img)

# 1. BGR to Grayscale (xám)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv.imshow('Grayscale', gray)

# 2. BGR to HSV (Hue-Saturation-Value)
# HSV tốt cho việc phát hiện màu sắc
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
cv.imshow('HSV', hsv)

# 3. BGR to LAB (L*a*b)
# LAB tốt cho color matching và comparison
lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)
cv.imshow('LAB', lab)

# 4. BGR to RGB
# RGB dùng cho matplotlib và các thư viện khác
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.imshow('RGB', rgb)

# 5. Chuyển ngược: LAB to BGR
lab_bgr = cv.cvtColor(lab, cv.COLOR_LAB2BGR)
cv.imshow('LAB --> BGR', lab_bgr)

cv.waitKey(0)
cv.destroyAllWindows()

print("Hoàn thành bài 6!")
print("\nGhi chú:")
print("- Grayscale: Giảm thông tin màu, tốt cho edge detection")
print("- HSV: Tách màu sắc khỏi độ sáng, tốt cho color detection")
print("- LAB: Perception-based, tốt cho color comparison")
print("- RGB: Standard format cho hầu hết applications")
# Out:
# Hoàn thành bài 6!
#
# Ghi chú:
# - Grayscale: Giảm thông tin màu, tốt cho edge detection
# - HSV: Tách màu sắc khỏi độ sáng, tốt cho color detection
# - LAB: Perception-based, tốt cho color comparison
# - RGB: Standard format cho hầu hết applications

# %% [markdown]
# ---
#
# ### Bài 7: Blurring (Làm Mờ)
#
# **Đề bài:**
# Áp dụng các kỹ thuật làm mờ khác nhau lên ảnh `Resources/Photos/cats.jpg`:
# 1. Average Blur
# 2. Gaussian Blur
# 3. Median Blur
# 4. Bilateral Filter
#
# So sánh kết quả của các phương pháp.
#
# **Mục tiêu học tập:**
# - Hiểu sự khác biệt giữa các kỹ thuật blur
# - Biết khi nào nên dùng blur nào
# - Sử dụng `cv.blur()`, `cv.GaussianBlur()`, `cv.medianBlur()`, `cv.bilateralFilter()`

# %%
### CODE GIẢI BÀI 7

import cv2 as cv

img = cv.imread('Resources/Photos/cats.jpg')
cv.imshow('Original Cats', img)

# 1. GAUSSIAN BLUR
# Sử dụng Gaussian kernel - pixels gần tâm có trọng số cao hơn
# Tốt hơn Average blur, giữ được edge tốt hơn
gaussian =cv.GaussianBlur(img,(3,3),cv.BORDER_DEFAULT)
cv.imshow('Gaussian Blur', gaussian)
# GiỚI THIỆU THÊM CHO CÁC BẠN 1 SỐ KỸ THUẬT KHÁC ANH CHƯA THẤY GIỚI THIỆU TRÊN LỚP
# 2. AVERAGE BLUR
# Lấy trung bình của tất cả pixels trong kernel
# Đơn giản nhưng có thể làm mất edge
average = cv.blur(img, (3, 3))
cv.imshow('Average Blur', average)

# 3. MEDIAN BLUR
# Lấy giá trị median thay vì mean
# Rất hiệu quả với salt-and-pepper noise
median = cv.medianBlur(img, 3)
cv.imshow('Median Blur', median)

# 4. BILATERAL FILTER
# Làm mờ nhưng VẪN GIỮ EDGE
# Chậm hơn nhưng kết quả tốt nhất
# Tham số: image, diameter, sigmaColor, sigmaSpace
bilateral = cv.bilateralFilter(img, 10, 35, 25)
cv.imshow('Bilateral Blur', bilateral)

cv.waitKey(0)
cv.destroyAllWindows()

print("Hoàn thành bài 7!")
print("\nSo sánh các phương pháp blur:")
print("- Average: Nhanh nhất, blur đồng đều")
print("- Gaussian: Blur tự nhiên hơn, ưu tiên pixels gần tâm")
print("- Median: Tốt cho noise, đặc biệt salt-and-pepper")
print("- Bilateral: Chậm nhất nhưng giữ edge tốt nhất")
# Out:
# Hoàn thành bài 7!
#
# So sánh các phương pháp blur:
# - Average: Nhanh nhất, blur đồng đều
# - Gaussian: Blur tự nhiên hơn, ưu tiên pixels gần tâm
# - Median: Tốt cho noise, đặc biệt salt-and-pepper
# - Bilateral: Chậm nhất nhưng giữ edge tốt nhất

# %% [markdown]
# ---
#
# ## BÀI TẬP TỔNG HỢP
#
# ### Bài 8: Bài Tập Tổng Hợp - Xử Lý Ảnh Hoàn Chỉnh
#
# **Đề bài:**
# Tạo một chương trình xử lý ảnh hoàn chỉnh với các bước sau:
#
# 1. Đọc ảnh `Resources/Photos/park.jpg`
# 2. Resize ảnh về 600x600 pixels
# 3. Chuyển sang HSV và tách các channels
# 4. Áp dụng Gaussian Blur với kernel 5x5
# 5. Phát hiện cạnh bằng Canny
# 6. Tìm và vẽ tất cả contours lên ảnh gốc
# 7. Thêm text thông tin: số contours tìm được
# 8. Lưu kết quả ra file
#
# **Mục tiêu:**
# - Kết hợp nhiều kỹ thuật đã học
# - Tạo pipeline xử lý ảnh hoàn chỉnh
# - Lưu kết quả ra file

# %%
### CODE GIẢI BÀI 8 - TỔNG HỢP

import cv2 as cv
import numpy as np

# Bước 1: Đọc ảnh
img=cv.imread('Resources/Photos/park.jpg')

# Bước 2: Resize
resized=cv.resize(img,(600,600))
cv.imshow('1. Resized', resized)

# Bước 3: Chuyển sang HSV
hsv = cv.cvtColor(resized, cv.COLOR_BGR2HSV)
cv.imshow('2. HSV', hsv)

# Tách channels HSV
h, s, v = cv.split(hsv)
cv.imshow('Hue Channel', h)
cv.imshow('Saturation Channel', s)
cv.imshow('Value Channel', v)

# Bước 4: Gaussian Blur trên ảnh gốc đã resize
gaussian = cv.GaussianBlur(resized,(5,5),cv.BORDER_DEFAULT)
cv.imshow('Gaussian Blur', gaussian)

# Bước 5: Chuyển sang grayscale và Canny Edge Detection
gray=cv.cvtColor(gaussian,cv.COLOR_BGR2GRAY)
cv.imshow('Grayscale', gray)
canny=cv.Canny(gray,120,150)
cv.imshow('Canny Edges', canny)

# Bước 6: Tìm contours
contours, hierarchies = cv.findContours(canny, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
num_contours = len(contours)
print(f"Số contours tìm được: {num_contours}")

# Vẽ contours lên ảnh gốc (tạo bản copy)
result = resized.copy()
cv.drawContours(result, contours, -1, (0, 255, 0), 2)

# Bước 7: Thêm text thông tin
text = f'Contours: {num_contours}'
cv.putText(result, text, (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

# Thêm watermark
cv.putText(result, 'OpenCV Project', (10, result.shape[0] - 10), 
           cv.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

cv.imshow('5. Final Result', result)

# Bước 8: Lưu kết quả
output_path = 'processed_park.jpg'
cv.imwrite(output_path, result)
print(f"Đã lưu kết quả vào: {output_path}")

# Tạo một composite image để so sánh
# Stack ảnh gốc và kết quả cạnh nhau
comparison = np.hstack([resized, result])
cv.imshow('6. Comparison: Original vs Processed', comparison)

cv.waitKey(0)
cv.destroyAllWindows()

print("\n" + "="*50)
print("HOÀN THÀNH BÀI TẬP TỔNG HỢP!")
print("="*50)
print(f"Tổng số contours phát hiện: {num_contours}")
print(f"Kích thước ảnh xử lý: {result.shape}")
print(f"File kết quả: {output_path}")
# Out:
# Số contours tìm được: 229
# Đã lưu kết quả vào: processed_park.jpg
#
# ...
# HOÀN THÀNH BÀI TẬP TỔNG HỢP!
# ...
# Tổng số contours phát hiện: 229
# Kích thước ảnh xử lý: (600, 600, 3)
# File kết quả: processed_park.jpg

# %% [markdown]
# ---
#
# ## BÀI TẬP THỰC HÀNH THÊM
# ## Đây là anh tự nghĩ và tự tìm hiểu để làm năm ngoái, các bạn có thể tự sáng tạo và tìm hiểu nếu chưa các kiến thức được cung cấp
#
# ### Bài 9: Thử Thách - Các bạn có thể tự sáng theo ý mình
#
# **Yêu cầu:**
# 1. Đọc một ảnh bất kỳ từ thư mục Resources
# 2. Tạo một creative effect bằng cách kết hợp:
#    - Ít nhất 3 color space transformations
#    - 2 loại blur khác nhau
#    - Masking với shape tự tạo
#    - Text và drawing
# 3. Lưu lại kết quả và giải thích từng bước
#
# **Mục tiêu:**
# - Sáng tạo và áp dụng kiến thức đã học
# - Hiểu sâu về cách các kỹ thuật kết hợp với nhau
#
# **Gợi ý:**
# - Thử tạo Instagram-like filters
# - Tạo vignette effect
# - Tạo artistic blur effects
# - Highlight một vùng cụ thể của ảnh

# %%
import cv2 as cv
import numpy as np

print("=" * 60)
print("BÀI 9: TẠO CREATIVE EFFECT - VIGNETTE & ARTISTIC FILTER")
print("=" * 60)

# Đọc ảnh
img = cv.imread('Resources/Photos/park.jpg')
cv.imshow('Original', img)

# Resize về kích thước chuẩn
img = cv.resize(img, (600, 600), interpolation=cv.INTER_AREA)

# BƯỚC 1: Color Space Transformations
print("\n[1] Chuyển đổi Color Spaces...")

# Chuyển sang LAB để điều chỉnh brightness
lab = cv.cvtColor(img, cv.COLOR_BGR2LAB)
l, a, b = cv.split(lab)

# Tăng độ sáng một chút
l = cv.add(l, 20)
enhanced_lab = cv.merge([l, a, b])
enhanced = cv.cvtColor(enhanced_lab, cv.COLOR_LAB2BGR)

# Chuyển sang HSV để tăng saturation
hsv = cv.cvtColor(enhanced, cv.COLOR_BGR2HSV)
h, s, v = cv.split(hsv)
s = cv.add(s, 30)  # Tăng saturation
vibrant_hsv = cv.merge([h, s, v])
vibrant = cv.cvtColor(vibrant_hsv, cv.COLOR_HSV2BGR)

cv.imshow('1. Enhanced Colors', vibrant)

# BƯỚC 2: Artistic Blur Effects
print("[2] Áp dụng Artistic Blur...")

# Bilateral filter để giữ edge nhưng smooth vùng phẳng
artistic = cv.bilateralFilter(vibrant, 15, 80, 80)

# Thêm một chút Gaussian blur nhẹ
artistic = cv.GaussianBlur(artistic, (3, 3), 0)

cv.imshow('2. Artistic Blur', artistic)

# BƯỚC 3: Tạo Vignette Effect
print("[3] Tạo Vignette Effect...")

# Tạo gradient mask từ tâm ra ngoài
rows, cols = artistic.shape[:2]
kernel_x = cv.getGaussianKernel(cols, cols/2)
kernel_y = cv.getGaussianKernel(rows, rows/2)
kernel = kernel_y * kernel_x.T
vignette_mask = kernel / kernel.max()

# Áp dụng vignette mask
vignette = artistic.copy()
for i in range(3):  # Áp dụng cho cả 3 channels BGR
    vignette[:, :, i] = vignette[:, :, i] * vignette_mask

cv.imshow('3. Vignette Effect', vignette)

# BƯỚC 4: Shape Masking - Highlight Center
print("[4] Tạo Center Highlight với Masking...")

# Tạo circular mask ở giữa
blank_mask = np.zeros((rows, cols), dtype='uint8')
center = (cols // 2, rows // 2)
radius = min(rows, cols) // 3

# Vẽ circle mask với gradient
cv.circle(blank_mask, center, radius, 255, -1)
blur_mask = cv.GaussianBlur(blank_mask, (101, 101), 0)

# Tạo highlighted version
highlighted = artistic.copy()
for i in range(3):
    highlighted[:, :, i] = cv.addWeighted(
        artistic[:, :, i], 0.5,
        vignette[:, :, i], 0.5,
        0
    )

# Blend original và highlighted dựa trên mask
result = vignette.copy()
for i in range(3):
    result[:, :, i] = np.where(
        blur_mask > 128,
        artistic[:, :, i],
        vignette[:, :, i]
    )

cv.imshow('4. Center Highlighted', result)

# BƯỚC 5: Thêm Text và Drawing
print("[5] Thêm Text và Decorations...")

final_result = result.copy()

# Vẽ khung viền
cv.rectangle(final_result, (10, 10), (590, 590), (255, 255, 255), 3)

# Thêm title
cv.putText(final_result, 'ARTISTIC VIGNETTE', (20, 50),
           cv.FONT_HERSHEY_DUPLEX, 1.2, (255, 255, 255), 2)

# Thêm subtitle
cv.putText(final_result, 'Creative OpenCV Filter', (20, 80),
           cv.FONT_HERSHEY_SIMPLEX, 0.7, (200, 200, 200), 1)

# Thêm watermark ở góc
cv.putText(final_result, 'OpenCV 2025', (420, 580),
           cv.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

# Vẽ một vài decorative circles
cv.circle(final_result, (50, 550), 15, (255, 200, 0), 2)
cv.circle(final_result, (550, 50), 15, (0, 200, 255), 2)

cv.imshow('5. FINAL RESULT - BÀI 10', final_result)

# Lưu kết quả
output_file = 'bai10_creative_result.jpg'
cv.imwrite(output_file, final_result)
print(f"\n✅ Đã lưu kết quả: {output_file}")

# So sánh before/after
comparison = np.hstack([
    cv.resize(img, (300, 300)),
    cv.resize(final_result, (300, 300))
])
cv.imshow('6. Before vs After', comparison)

print("\n" + "=" * 60)
print("HOÀN THÀNH BÀI 9!")
print("=" * 60)
print("\nKỹ thuật đã sử dụng:")
print("✓ 3 Color Spaces: LAB, HSV, BGR")
print("✓ 2 Blur Methods: Bilateral + Gaussian")
print("✓ Vignette Effect với Gaussian Kernel")
print("✓ Circular Masking với Gradient")
print("✓ Text, Shapes và Decorations")
print("=" * 60)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ...
# BÀI 9: TẠO CREATIVE EFFECT - VIGNETTE & ARTISTIC FILTER
# ...
#
# [1] Chuyển đổi Color Spaces...
# [2] Áp dụng Artistic Blur...
# [3] Tạo Vignette Effect...
# [4] Tạo Center Highlight với Masking...
# [5] Thêm Text và Decorations...
#
# ✅ Đã lưu kết quả: bai10_creative_result.jpg
#
# ...
# HOÀN THÀNH BÀI 9!
# ...
#
# Kỹ thuật đã sử dụng:
# ✓ 3 Color Spaces: LAB, HSV, BGR
# ✓ 2 Blur Methods: Bilateral + Gaussian
# ✓ Vignette Effect với Gaussian Kernel
# ✓ Circular Masking với Gradient
# ✓ Text, Shapes và Decorations
# ...

# %% [markdown]
# ## Bài 10: Xử Lý Video - Extract & Process Frames
#
# ### Đề bài:
#
# Làm việc với video để trích xuất frames và xử lý từng frame một:
#
# **Yêu cầu:**
#
# **Phần 1: Đọc và phân tích video**
# 1. Đọc video từ `Resources/Videos/dog.mp4`
# 2. Lấy và hiển thị thông tin video:
#    - FPS (frames per second)
#    - Tổng số frames
#    - Kích thước (width x height)
#    - Thời lượng (duration)
#
# **Phần 2: Trích xuất frames**
# 3. Trích xuất 5-10 frames từ video
# 4. Lưu các frames vào thư mục `extracted_frames/`
# 5. Đặt tên file theo format: `frame_0000.jpg`, `frame_0001.jpg`, ...
#
# **Phần 3: Xử lý các frames đã trích xuất**
# 6. Đọc lại các frames đã lưu
# 7. Áp dụng **4 kỹ thuật xử lý** lên mỗi frame:
#    - **Grayscale**: Chuyển sang ảnh xám
#    - **Edge Detection**: Phát hiện cạnh với Canny
#    - **Cartoon Effect**: Kết hợp bilateral filter + adaptive threshold
#    - **Brightness**: Tăng độ sáng qua HSV
# 8. Tạo composite image với 4 views (2x2 grid):
#    - Top-left: Original
#    - Top-right: Grayscale
#    - Bottom-left: Edges
#    - Bottom-right: Cartoon
# 9. Thêm labels cho mỗi view
# 10. Lưu các composite images vào thư mục `processed_frames/`
#
# **Phần 4: Hiển thị video với effects**
# 11. Đọc lại video từ đầu
# 12. Hiển thị video với real-time cartoon effect
# 13. So sánh Original vs Processed cạnh nhau
# 14. Cho phép nhấn 'd' để dừng
#
# **Mục tiêu học tập:**
# - Đọc và phân tích video với `cv.VideoCapture()`
# - Trích xuất frames từ video
# - Xử lý batch nhiều frames
# - Tạo cartoon effect
# - Hiển thị video real-time
# - Tạo composite multi-view images
#
# **Kiến thức cần dùng:**
# - `cv.VideoCapture()` - Đọc video
# - `cap.get(cv.CAP_PROP_FPS)` - Lấy FPS
# - `cap.get(cv.CAP_PROP_FRAME_COUNT)` - Lấy tổng frames
# - `cap. read()` - Đọc frame
# - `cv.bilateralFilter()` - Smooth nhưng giữ edge
# - `cv.adaptiveThreshold()` - Threshold động
# - `np.hstack()`, `np.vstack()` - Stack images
#
# **Cartoon Effect Algorithm:**
# ```
# 1. Apply bilateral filter (smooth but keep edges)
# 2. Convert to grayscale
# 3. Apply median blur
# 4. Apply adaptive threshold to get edges
# 5. Combine blurred color với edge mask
# ```
#
# **Tips:**
# - Để extract đều, lấy 1 frame mỗi giây: `if frame_count % fps == 0`
# - Adaptive threshold parameters: blockSize=9, C=2
# - Bilateral filter cho cartoon: diameter=9, sigma=75

# %%
# ============================================================
# BÀI 10: XỬ LÝ VIDEO - EXTRACT & PROCESS FRAMES
# ============================================================

print("\n\n")
print("=" * 60)
print("BÀI 10: XỬ LÝ VIDEO - EXTRACT & PROCESS FRAMES")
print("=" * 60)

# Đọc video
video_path = 'Resources/Videos/dog.mp4'
cap = cv.VideoCapture(video_path)

if not cap.isOpened():
    print("❌ Không thể mở video!")
    exit()

# Lấy thông tin video
fps = int(cap.get(cv.CAP_PROP_FPS))
total_frames = int(cap.get(cv.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))

print(f"\n📹 Thông tin video:")
print(f"   - FPS: {fps}")
print(f"   - Tổng số frames: {total_frames}")
print(f"   - Kích thước: {width}x{height}")
print(f"   - Thời lượng: {total_frames/fps:.2f} giây")

# PHẦN 1: Extract frames định kỳ
print(f"\n[1] Trích xuất frames mỗi {fps} frame (1 frame/giây)...")

import os
output_dir = 'extracted_frames'
os.makedirs(output_dir, exist_ok=True)

frame_count = 0
extracted_count = 0
extract_interval = fps  # Lấy 1 frame mỗi giây

while True:
    ret, frame = cap.read()
    
    if not ret:
        break
    
    # Extract frame định kỳ
    if frame_count % extract_interval == 0:
        filename = f'{output_dir}/frame_{extracted_count:04d}.jpg'
        cv.imwrite(filename, frame)
        extracted_count += 1
        print(f"   ✓ Đã lưu: {filename}")
    
    frame_count += 1

print(f"\n✅ Đã trích xuất {extracted_count} frames vào thư mục '{output_dir}/'")

# Reset video về đầu
cap.set(cv.CAP_PROP_POS_FRAMES, 0)

# PHẦN 2: Xử lý video real-time
print(f"\n[2] Xử lý video real-time với các hiệu ứng...")
print("   Nhấn 'd' để thoát, 'p' để pause/resume")

# Tạo video writer để lưu kết quả
output_video = 'processed_video.avi'
fourcc = cv.VideoWriter_fourcc(*'XVID')
out = cv.VideoWriter(output_video, fourcc, fps, (width, height))

frame_num = 0
paused = False

while True:
    if not paused:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        # === XỬ LÝ FRAME ===
        
        # 1. Chuyển sang grayscale
        gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
        gray_bgr = cv.cvtColor(gray, cv.COLOR_GRAY2BGR)
        
        # 2. Edge detection
        edges = cv.Canny(gray, 50, 150)
        edges_bgr = cv.cvtColor(edges, cv.COLOR_GRAY2BGR)
        
        # 3. Cartoon effect
        # Bilateral filter + edge detection
        cartoon = cv.bilateralFilter(frame, 9, 75, 75)
        cartoon_gray = cv.cvtColor(cartoon, cv.COLOR_BGR2GRAY)
        cartoon_blur = cv.medianBlur(cartoon_gray, 7)
        cartoon_edges = cv.adaptiveThreshold(
            cartoon_blur, 255,
            cv.ADAPTIVE_THRESH_MEAN_C,
            cv.THRESH_BINARY, 9, 2
        )
        cartoon_edges_bgr = cv.cvtColor(cartoon_edges, cv.COLOR_GRAY2BGR)
        cartoon_final = cv.bitwise_and(cartoon, cartoon_edges_bgr)
        
        # 4. Color modification (HSV)
        hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
        h, s, v = cv.split(hsv)
        s = cv.add(s, 50)  # Tăng saturation
        vibrant_hsv = cv.merge([h, s, v])
        vibrant_frame = cv.cvtColor(vibrant_hsv, cv.COLOR_HSV2BGR)
        
        # === TẠO COMPOSITE ===
        
        # Resize các frame để hiển thị 4 cùng lúc
        h_half, w_half = height // 2, width // 2
        
        original_small = cv.resize(frame, (w_half, h_half))
        gray_small = cv.resize(gray_bgr, (w_half, h_half))
        edges_small = cv.resize(edges_bgr, (w_half, h_half))
        cartoon_small = cv.resize(cartoon_final, (w_half, h_half))
        
        # Thêm labels
        cv.putText(original_small, 'Original', (10, 30),
                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv.putText(gray_small, 'Grayscale', (10, 30),
                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
        cv.putText(edges_small, 'Edges', (10, 30),
                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        cv.putText(cartoon_small, 'Cartoon', (10, 30),
                   cv.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 255), 2)
        
        # Stack frames
        top_row = np.hstack([original_small, gray_small])
        bottom_row = np.hstack([edges_small, cartoon_small])
        composite = np.vstack([top_row, bottom_row])
        
        # Hiển thị
        cv.imshow('Video Processing - 4 Views', composite)
        
        # Lưu frame đã xử lý (cartoon effect) vào output video
        out.write(cartoon_final)
        
        frame_num += 1
        
        # Hiển thị progress
        if frame_num % fps == 0:
            progress = (frame_num / total_frames) * 100
            print(f"   Processing: {progress:.1f}% ({frame_num}/{total_frames} frames)")
    
    # Xử lý keyboard input
    key = cv.waitKey(20) & 0xFF
    if key == ord('d'):
        print("\n⏹ Dừng xử lý video")
        break
    elif key == ord('p'):
        paused = not paused
        status = "PAUSED" if paused else "RESUMED"
        print(f"   ⏸ {status}")

# Clean up
cap.release()
out.release()
cv.destroyAllWindows()

print(f"\n✅ Đã lưu video đã xử lý: {output_video}")

# Thống kê frames đã lưu
frame_files = [f for f in os.listdir(output_dir) if f.endswith('.jpg')]
print(f"\n📊 Thống kê:")
print(f"   - Frames đã trích xuất: {len(frame_files)} files")
print(f"   - Frames đã xử lý: {frame_num} frames")
print(f"   - Thư mục frames: {output_dir}/")
print(f"   - Video output: {output_video}")

print("\n" + "=" * 60)
print("HOÀN THÀNH BÀI 10!")
print("=" * 60)
print("\nĐã học:")
print("✓ Đọc video với VideoCapture")
print("✓ Lấy thông tin video (FPS, frames, kích thước)")
print("✓ Extract frames định kỳ và lưu file")
print("✓ Xử lý video real-time với nhiều hiệu ứng")
print("✓ Tạo composite view (4 views cùng lúc)")
print("✓ Ghi video đã xử lý với VideoWriter")
print("✓ Pause/Resume video processing")
print("=" * 60)

print(f"\n💡 THỰC HÀNH:")
print(f"   1. Mở thư mục '{output_dir}/' để xem các frames đã trích xuất")
print(f"   2. Mở file '{output_video}' để xem video cartoon effect")
print(f"   3. Thử thay đổi các tham số blur, edge detection")
print(f"   4. Thử thêm các hiệu ứng khác (color filters, etc.)")
# Out:
# ...
# BÀI 10: XỬ LÝ VIDEO - EXTRACT & PROCESS FRAMES
# ...
#
# 📹 Thông tin video:
#    - FPS: 29
#    - Tổng số frames: 336
#    - Kích thước: 1280x720
#    - Thời lượng: 11.59 giây
#
# [1] Trích xuất frames mỗi 29 frame (1 frame/giây)...
#    ✓ Đã lưu: extracted_frames/frame_0000.jpg
#    ✓ Đã lưu: extracted_frames/frame_0001.jpg
#    ✓ Đã lưu: extracted_frames/frame_0002.jpg
#    ✓ Đã lưu: extracted_frames/frame_0003.jpg
#    ✓ Đã lưu: extracted_frames/frame_0004.jpg
#    ✓ Đã lưu: extracted_frames/frame_0005.jpg
#    ✓ Đã lưu: extracted_frames/frame_0006.jpg
#    ✓ Đã lưu: extracted_frames/frame_0007.jpg
#    ✓ Đã lưu: extracted_frames/frame_0008.jpg
#    ✓ Đã lưu: extracted_frames/frame_0009.jpg
#    ✓ Đã lưu: extracted_frames/frame_0010.jpg
#    ✓ Đã lưu: extracted_frames/frame_0011.jpg
#
# ✅ Đã trích xuất 12 frames vào thư mục 'extracted_frames/'
#
# [2] Xử lý video real-time với các hiệu ứng...
#    Nhấn 'd' để thoát, 'p' để pause/resume
#
# ⏹ Dừng xử lý video
#
# ...

# %% [markdown]
# ---
#
# ## TÀI LIỆU THAM KHẢO
#
# ### OpenCV Documentation
# - [Official OpenCV Documentation](https://docs.opencv.org/)
# - [OpenCV Python Tutorials](https://docs.opencv.org/master/d6/d00/tutorial_py_root.html)
#
# ### Video Tutorial
# - [freeCodeCamp OpenCV Course](https://youtu.be/oXlwWbU8l2o)
#
# ### Mẹo Học Tập
# 1. **Thực hành thường xuyên**: Chạy code và thử nghiệm với các tham số khác nhau
# 2. **Đọc documentation**: Hiểu rõ từng parameter của hàm
# 3. **Debug bằng visualization**: Luôn hiển thị kết quả trung gian
# 4. **Thử với ảnh riêng**: Áp dụng vào ảnh của chính bạn
# 5. **Kết hợp kỹ thuật**: Thử kết hợp nhiều kỹ thuật để tạo hiệu ứng mới
#
# ### Color Codes Reference (BGR)
# ```python
# BLACK = (0, 0, 0)
# WHITE = (255, 255, 255)
# RED = (0, 0, 255)
# GREEN = (0, 255, 0)
# BLUE = (255, 0, 0)
# YELLOW = (0, 255, 255)
# CYAN = (255, 255, 0)
# MAGENTA = (255, 0, 255)
# ```
#
# ### Common Issues và Solutions
#
# **1. Ảnh không hiển thị:**
# - Kiểm tra đường dẫn file
# - Đảm bảo có `cv.waitKey(0)`
#
# **2. Kernel size error:**
# - Kernel phải là số lẻ (3, 5, 7, ...)
# - Kernel phải là tuple (x, y)
#
# **3. Color không đúng:**
# - Remember: OpenCV uses BGR, not RGB
# - Chuyển đổi khi cần: `cv.cvtColor(img, cv.COLOR_BGR2RGB)`
#
# ---
#
# ## KẾT LUẬN
#
# Chúc các em học tốt! Hãy thực hành nhiều và đừng ngại thử nghiệm.
#
# **Nhớ rằng**: Computer Vision là về việc hiểu cách máy tính "nhìn" thế giới. Mỗi kỹ thuật bạn học đều là một công cụ để giúp máy tính hiểu ảnh tốt hơn.
#
# **Next Steps:**
# 1. Hoàn thành tất cả bài tập
# 2. Tìm hiểu trước cho anh FastAPI
#
# ---
#
# **GitHub**: https://github.com/jasmcaus/opencv-course
